# %%
# Data Preprocessing
    # Importing the libraries
    # Cleaning the data
    # Split into training and test set
# Modelling
    # Build the model
    # Train the model
    # Make predictions

# Evaluating
    # Calculate the performance metrics
    # Make a verdict

# %%
# Train test split
# 80 - 20 rule
# 80% of the data for training
# 20% of the data for testing

# %% [markdown]
# Feature Scaling (always applies to columns with numerical values)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Feature Scaling
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
